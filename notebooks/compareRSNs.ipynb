# %% [markdown]
# # Compare RSN structure in DyNeuSRs between empirical and null data

# %%
from utils import *
# %pylab nbagg
import pickle

with open('nx_graphs.p', 'rb') as f:
    Greals = pickle.load(f)
with open('null_graphs.p', 'rb') as f:
    Gnulls = pickle.load(f)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/rafi/miniconda/envs/dyno/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['product', 'f']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ### Examine induced subgraphs of specific RSNs

# %% [markdown]
# Take the original graph and extract only the nodes that have an activation of a particular RSN.

# %%
def drawRSN(G,rsn):
    plt.close('all')
    # Pull nodes belonging to the RSN
    subnodes = [node for node in G.nodes() if G.node[node]['group'][rsn]]
    # Extract subgraph
    subG = G.subgraph(subnodes)
    # Draw graph
    nx.draw_spring(subG)
    plt.show()

# %%
drawRSN(Greals[80],'Somatomotor')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
drawRSN(Gnulls[80],'Somatomotor')
# Out:
# <img src="data:image/png;base64,..." width="640">
